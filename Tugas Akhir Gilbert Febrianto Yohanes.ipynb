# %% [markdown]
# # Sample Data

# %% [markdown]
# ##Retrieve YouTube Transcript with API Data Scraping

# %%
pip install youtube-transcript-api
# Out:
# Collecting youtube-transcript-api
#   Downloading youtube_transcript_api-0.6.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from youtube-transcript-api) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->youtube-transcript-api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->youtube-transcript-api) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->youtube-transcript-api) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->youtube-transcript-api) (2023.7.22)
# Installing collected packages: youtube-transcript-api
# Successfully installed youtube-transcript-api-0.6.1

# %%
from youtube_transcript_api import YouTubeTranscriptApi

# Example YouTube video URL
youtube_url = 'https://www.youtube.com/watch?v=z6ep308goxQ'

# Extract the video ID from the URL
video_id = youtube_url.split('v=')[1]

# Get the transcript for the video using the video ID
transcript = YouTubeTranscriptApi.get_transcript(video_id)

# Now you can work with the transcript data
transcript
# Out:
# [{'text': '- The internet in Japan looks different.',
#   'start': 0.21,
#   'duration': 2.64},
#  {'text': 'In a world of minimalist\ndesigns and large clean images,',
#   'start': 2.85,
#   'duration': 2.88},
#  {'text': 'websites in Japan seem to mirror', 'start': 5.73, 'duration': 1.59},
#  {'text': 'the language and culture of their home,',
#   'start': 7.32,
#   'duration': 2.4},
#  {'text': 'colorful and a little cramped.', 'start': 9.72, 'duration': 2.46},
#  {'text': "At least that's according to\na theory I read back in 2013",
#   'start': 12.18,
#   'duration': 2.58},
#  {'text': 'and have shared with a\nbunch of people since.',
#   'start': 14.76,
#   'duration': 2.31},
#  {'text': "There's just one problem.", 'start': 17.07, 'duration': 1.47},
#  {'text': "I don't know if it's\ntrue, so let's fix that.",
#   'start': 18.54,
#   'duration': 3.93},
#  {'text': 'In this video, we use an AI to figure out',
#   'start': 22.47,
#   'duration': 2.37},
#  {'text': "what's so special about\nJapanese web design",
#   'start': 24.84,
#   'duration': 2.73},
#  {'text': 'and how even across an\nocean it impacts you today.',
#   'start': 27.57,
#   'duration': 3.36},
#  {'text': 'I think I might give up.', 'start': 30.93, 'duration': 1.08},
#  {'text': 'Thank you to Hostinger\nfor sponsoring this video.',
#   'start': 32.01,
#   'duration': 2.4},
#  {'text': "Let's start off with how I realized",
#   'start': 34.41,
#   'duration': 1.62},
#  {'text': 'that I may have been lying to\npeople for the past decade.',
#   'start': 36.03,
#   'duration': 2.4},
#  {'text': 'I was setting up a website\nto document an old project.',
#   'start': 38.43,
#   'duration': 2.46},
#  {'text': 'While scrolling through the templates,',
#   'start': 40.89,
#   'duration': 1.35},
#  {'text': 'the following three thoughts\npassed through my head.',
#   'start': 42.24,
#   'duration': 2.43},
#  {'text': 'One, "Wow, these themes\nare really minimalist."',
#   'start': 44.67,
#   'duration': 2.7},
#  {'text': 'Two, "Remember how Japan, a\nnation known for minimalism,',
#   'start': 47.37,
#   'duration': 3.21},
#  {'text': 'ironically has really cluttered webpages?"',
#   'start': 50.58,
#   'duration': 2.73},
#  {'text': 'And three, "How did I know that?"',
#   'start': 53.31,
#   'duration': 2.79},
#  {'text': 'Has that ever happened to you?', 'start': 56.1, 'duration': 1.11},
#  {'text': "Like you accept something\nas fact when you're a kid,",
#   'start': 57.21,
#   'duration': 1.83},
#  {'text': 'but now that your prefrontal\ncortex has finished developing,',
#   'start': 59.04,
#   'duration': 2.91},
#  {'text': "you think back and you're like,", 'start': 61.95, 'duration': 2.13},
#  {'text': 'hold on, my spider sense is tingling.',
#   'start': 64.08,
#   'duration': 1.98},
#  {'text': 'What could possibly be\nso special about Japan',
#   'start': 66.06,
#   'duration': 2.19},
#  {'text': 'that they just decide to have\ndifferent web design practices',
#   'start': 68.25,
#   'duration': 2.76},
#  {'text': 'than the rest of the world apparently?',
#   'start': 71.01,
#   'duration': 2.25},
#  {'text': 'And even if the article was\ntrue, it came out 10 years ago.',
#   'start': 73.26,
#   'duration': 3.48},
#  {'text': "I don't know if it's still\ntrue. This is the internet.",
#   'start': 76.74,
#   'duration': 2.85},
#  {'text': 'Twitter was normal one day', 'start': 79.59, 'duration': 1.77},
#  {'text': 'and then it might be dead\nby the time you watch this,',
#   'start': 81.36,
#   'duration': 2.43},
#  {'text': 'to be honest.', 'start': 83.79, 'duration': 0.833},
#  {'text': 'The internet moves fast.', 'start': 84.623, 'duration': 1.237},
#  {'text': 'So in this video, I wanna put\nthe theory to a modern test.',
#   'start': 85.86,
#   'duration': 3.45},
#  {'text': 'I wanna see if there is something unique',
#   'start': 89.31,
#   'duration': 1.77},
#  {'text': 'about Japanese web design,\nand if there is, why?',
#   'start': 91.08,
#   'duration': 3.75},
#  {'text': 'Am I just overcompensating', 'start': 94.83, 'duration': 1.5},
#  {'text': "because I realize I've\nbeen doing misinformation?",
#   'start': 96.33,
#   'duration': 2.523},
#  {'text': 'Probably.', 'start': 99.75, 'duration': 1.74},
#  {'text': "Let's do this.", 'start': 101.49, 'duration': 1.23},
#  {'text': 'So I tweeted this, "Are you in Asia?',
#   'start': 102.72,
#   'duration': 1.92},
#  {'text': 'Have you been using the internet',
#   'start': 104.64,
#   'duration': 1.23},
#  {'text': 'over the past 5 to 10 years?', 'start': 105.87, 'duration': 1.74},
#  {'text': 'Please hit me up."', 'start': 107.61, 'duration': 0.833},
#  {'text': 'And it worked, my DMs\nare completely destroyed,',
#   'start': 108.443,
#   'duration': 2.017},
#  {'text': 'but I have been chatting with\na bunch of awesome people',
#   'start': 110.46,
#   'duration': 2.37},
#  {'text': "and no one really knows\nwhat I'm talking about.",
#   'start': 112.83,
#   'duration': 3.27},
#  {'text': "I am so worried this\nvideo's gonna go nowhere.",
#   'start': 116.1,
#   'duration': 2.43},
#  {'text': 'I took those replies to mean\nthat this web design thing',
#   'start': 118.53,
#   'duration': 2.34},
#  {'text': 'really might just be isolated to Japan.',
#   'start': 120.87,
#   'duration': 2.67},
#  {'text': 'So I decided to verify', 'start': 123.54, 'duration': 1.44},
#  {'text': 'by checking out the most popular websites',
#   'start': 124.98,
#   'duration': 2.34},
#  {'text': 'in every country in the world.', 'start': 127.32, 'duration': 1.5},
#  {'text': 'So many of these websites are just Google',
#   'start': 128.82,
#   'duration': 2.73},
#  {'text': 'or manga reading websites.', 'start': 131.55, 'duration': 1.56},
#  {'text': "Are we just all weebs\nwho don't know things?",
#   'start': 133.11,
#   'duration': 2.64},
#  {'text': 'I categorized the websites\nbased on their contents.',
#   'start': 135.75,
#   'duration': 2.46},
#  {'text': "Okay, I know that this\nshouldn't surprise me,",
#   'start': 138.21,
#   'duration': 1.89},
#  {'text': 'but the internet is full of\na lot of not great stuff.',
#   'start': 140.1,
#   'duration': 4.08},
#  {'text': 'Just looking at some of these categories,',
#   'start': 144.18,
#   'duration': 1.62},
#  {'text': "we've got explicit, illegal,\nspam, suspected malware.",
#   'start': 145.8,
#   'duration': 4.68},
#  {'text': "I'm just gonna whoop.", 'start': 150.48, 'duration': 1.92},
#  {'text': 'I then accessed each website\nusing a web crawler and a VPN',
#   'start': 152.4,
#   'duration': 3.18},
#  {'text': 'to take screenshots of the local page.',
#   'start': 155.58,
#   'duration': 2.04},
#  {'text': 'So because of GDPR,', 'start': 157.62, 'duration': 1.41},
#  {'text': 'websites will ask you if you\nwant cookies, which I respect,',
#   'start': 159.03,
#   'duration': 3.03},
#  {'text': 'except that popup blocks\nthe entire freaking webpage.',
#   'start': 162.06,
#   'duration': 4.02},
#  {'text': 'So I need to figure out', 'start': 166.08, 'duration': 0.87},
#  {'text': 'how to say accept cookies or allow cookies',
#   'start': 166.95,
#   'duration': 1.95},
#  {'text': 'or, okay, cool, cookies in every language.',
#   'start': 168.9,
#   'duration': 4.17},
#  {'text': 'I thought computers were\nsupposed to make things easy.',
#   'start': 173.07,
#   'duration': 2.28},
#  {'text': 'Just look at this.', 'start': 175.35, 'duration': 1.35},
#  {'text': "Also, the way that they've implemented",
#   'start': 176.7,
#   'duration': 2.13},
#  {'text': 'these buttons are different.', 'start': 178.83, 'duration': 1.23},
#  {'text': "So I don't just need to know the language,",
#   'start': 180.06,
#   'duration': 1.38},
#  {'text': 'I need to find the specific\nbutton element to click',
#   'start': 181.44,
#   'duration': 3.48},
#  {'text': 'and then code it in.', 'start': 184.92, 'duration': 1.68},
#  {'text': 'I think I might give up.', 'start': 186.6, 'duration': 1.11},
#  {'text': 'Okay, so I now have 2,671 screenshots',
#   'start': 187.71,
#   'duration': 5.0},
#  {'text': 'of websites across like 200 countries.',
#   'start': 192.81,
#   'duration': 2.64},
#  {'text': "Ideally, I'd like to know how each website",
#   'start': 195.45,
#   'duration': 1.83},
#  {'text': 'compares to every other website,',
#   'start': 197.28,
#   'duration': 2.07},
#  {'text': 'but that would mean doing like', 'start': 199.35, 'duration': 1.5},
#  {'text': '3 million comparisons.', 'start': 203.28, 'duration': 2.13},
#  {'text': 'My brain is too soft and small to do that,',
#   'start': 205.41,
#   'duration': 2.79},
#  {'text': 'but luckily we have computers.', 'start': 208.2, 'duration': 1.89},
#  {'text': 'So I ended up using machine learning',
#   'start': 210.09,
#   'duration': 1.47},
#  {'text': 'to extract the most prominent features',
#   'start': 211.56,
#   'duration': 1.5},
#  {'text': 'of each website screenshot.', 'start': 213.06, 'duration': 1.44},
#  {'text': 'I then compared those\nextractions to one another',
#   'start': 214.5,
#   'duration': 2.1},
#  {'text': 'using a statistical method\nof dimensionality reduction',
#   'start': 216.6,
#   'duration': 2.49},
#  {'text': 'called t-distributed\nstochastic neighbor embeddings.',
#   'start': 219.09,
#   'duration': 2.7},
#  {'text': 'Please come back.', 'start': 221.79, 'duration': 0.833},
#  {'text': 'All you need to know is\nthat this lets us see',
#   'start': 222.623,
#   'duration': 1.777},
#  {'text': 'how our AI organizes and\ngroups our website screenshots.',
#   'start': 224.4,
#   'duration': 4.02},
#  {'text': 'The closer it puts screenshots together,',
#   'start': 228.42,
#   'duration': 1.71},
#  {'text': 'the more similar their designs,',
#   'start': 230.13,
#   'duration': 1.71},
#  {'text': 'and the further apart\nmeans more dissimilar.',
#   'start': 231.84,
#   'duration': 2.25},
#  {'text': "That's all I'm doing.", 'start': 234.09, 'duration': 0.833},
#  {'text': "So now let's run this.", 'start': 234.923, 'duration': 2.647},
#  {'text': 'Kind of anti-climactic.', 'start': 237.57, 'duration': 2.1},
#  {'text': 'So this is how the AI\norganized our websites.',
#   'start': 239.67,
#   'duration': 2.46},
#  {'text': 'So many pictures, so little resolution.',
#   'start': 242.13,
#   'duration': 2.61},
#  {'text': 'But if you look closely,', 'start': 244.74, 'duration': 0.833},
#  {'text': 'there are clumps that\nhave started to form.',
#   'start': 245.573,
#   'duration': 1.567},
#  {'text': "We've got Facebook, Google,", 'start': 247.14, 'duration': 2.7},
#  {'text': 'websites that would not let me in.',
#   'start': 249.84,
#   'duration': 2.43},
#  {'text': 'Twitter and Wikipedia.', 'start': 252.27, 'duration': 2.07},
#  {'text': 'But the thing is,', 'start': 254.34, 'duration': 0.833},
#  {'text': 'is that these websites are\nmore exception than the rule.',
#   'start': 255.173,
#   'duration': 2.587},
#  {'text': "They aren't representative\nof any nation's design style",
#   'start': 257.76,
#   'duration': 2.37},
#  {'text': 'because they are in\nbasically every nation.',
#   'start': 260.13,
#   'duration': 2.58},
#  {'text': "So I'm not gonna care about them.",
#   'start': 262.71,
#   'duration': 1.38},
#  {'text': 'Instead, what I do care\nabout is this thing,',
#   'start': 264.09,
#   'duration': 3.87},
#  {'text': 'what I like to call the clump of interest.',
#   'start': 267.96,
#   'duration': 3.84},
#  {'text': 'If we look closely at this clump,',
#   'start': 271.8,
#   'duration': 1.68},
#  {'text': "we can see that it's\nsorted along two axes.",
#   'start': 273.48,
#   'duration': 3.48},
#  {'text': "Vertically, it's pretty obvious,\nit goes from dark to light,",
#   'start': 276.96,
#   'duration': 2.61},
#  {'text': "but horizontally, you probably can't tell",
#   'start': 279.57,
#   'duration': 4.02},
#  {'text': "because you can't see anything.",
#   'start': 283.59,
#   'duration': 0.99},
#  {'text': 'But on the left side,', 'start': 284.58, 'duration': 0.833},
#  {'text': "we've got images with\na lot of empty space,",
#   'start': 285.413,
#   'duration': 1.897},
#  {'text': 'a little bit of text, very simple images.',
#   'start': 287.31,
#   'duration': 2.04},
#  {'text': 'As we move to the middle,', 'start': 289.35, 'duration': 0.96},
#  {'text': 'we have larger images and two\nor three columns of content.',
#   'start': 290.31,
#   'duration': 3.42},
#  {'text': 'But finally, as we move\nfurthest to the right,',
#   'start': 293.73,
#   'duration': 1.65},
#  {'text': 'we have a lot going on.', 'start': 295.38, 'duration': 1.35},
#  {'text': 'A whole bunch of columns,\nreally tiny images,',
#   'start': 296.73,
#   'duration': 2.55},
#  {'text': 'often of content that I cannot show you.',
#   'start': 299.28,
#   'duration': 3.09},
#  {'text': 'I tried so hard to filter.', 'start': 302.37, 'duration': 1.53},
#  {'text': 'The internet just has so much...',
#   'start': 303.9,
#   'duration': 2.43},
#  {'text': "I'm sorry.", 'start': 306.33, 'duration': 0.99},
#  {'text': 'Anyway, those are the visual\npatterns that guide this clump.',
#   'start': 307.32,
#   'duration': 3.15},
#  {'text': 'Now, where does Japan fit in?', 'start': 310.47, 'duration': 2.34},
#  {'text': "Oh, yeah, I've just changed", 'start': 312.81, 'duration': 0.833},
#  {'text': 'all the screenshots to little circles',
#   'start': 313.643,
#   'duration': 1.597},
#  {'text': 'to make it easier to\nsee things more clearly.',
#   'start': 315.24,
#   'duration': 2.61},
#  {'text': 'So, Japan, ta-dah.', 'start': 317.85, 'duration': 2.04},
#  {'text': "It's the red dots.", 'start': 319.89, 'duration': 1.05},
#  {'text': "We've got a little Google over there.",
#   'start': 320.94,
#   'duration': 1.68},
#  {'text': 'Right off the bat,', 'start': 322.62, 'duration': 0.833},
#  {'text': 'we can see that it kind of\navoids this sector up here,',
#   'start': 323.453,
#   'duration': 2.527},
#  {'text': "but we don't know if that\nis a common distribution.",
#   'start': 325.98,
#   'duration': 2.82},
#  {'text': 'Maybe a bunch of other\ncountries avoid this corner.',
#   'start': 328.8,
#   'duration': 2.04},
#  {'text': 'We need to compare.', 'start': 330.84, 'duration': 0.84},
#  {'text': "So let's see how it compares\nagainst the United States,",
#   'start': 331.68,
#   'duration': 3.48},
#  {'text': 'Canada, the UK, Ukraine,\nIndonesia, Mexico.',
#   'start': 335.16,
#   'duration': 4.65},
#  {'text': 'Are you seeing this?', 'start': 339.81, 'duration': 0.84},
#  {'text': 'All of the countries have\nwide varieties of web design',
#   'start': 340.65,
#   'duration': 3.33},
#  {'text': 'except for Japan.', 'start': 343.98, 'duration': 1.32},
#  {'text': 'Japan seems to be avoiding this sector',
#   'start': 345.3,
#   'duration': 2.37},
#  {'text': 'that is defined by dark, empty spaces.',
#   'start': 347.67,
#   'duration': 3.39},
#  {'text': "In other words, Japan's websites",
#   'start': 351.06,
#   'duration': 1.53},
#  {'text': 'are brightly colored and dense,\njust like the theory claims.',
#   'start': 352.59,
#   'duration': 3.99},
#  {'text': 'Did I just prove something?', 'start': 356.58, 'duration': 1.53},
#  {'text': "I'm genuinely surprised\nthat we found something.",
#   'start': 358.11,
#   'duration': 2.64},
#  {'text': 'I just wish you could see it better.',
#   'start': 360.75,
#   'duration': 2.52},
#  {'text': 'Oh, wait, you can.', 'start': 363.27, 'duration': 1.5},
#  {'text': 'I made a website.', 'start': 364.77, 'duration': 1.2},
#  {'text': 'It has everything that has been',
#   'start': 365.97,
#   'duration': 1.86},
#  {'text': 'and will be in this video and more.',
#   'start': 367.83,
#   'duration': 2.97},
#  {'text': 'Is this my methodology of the\nproject from start to finish?',
#   'start': 370.8,
#   'duration': 3.06},
#  {'text': 'Are those side by side\ncomparisons over time?',
#   'start': 373.86,
#   'duration': 2.25},
#  {'text': 'A full resolution photo\nof the plot I projected?',
#   'start': 376.11,
#   'duration': 2.85},
#  {'text': "And here's how I did it.", 'start': 378.96, 'duration': 0.93},
#  {'text': "I went to Hostinger, who's\nsponsoring this video,",
#   'start': 379.89,
#   'duration': 2.07},
#  {'text': 'and I checked out their plans.', 'start': 381.96, 'duration': 1.29},
#  {'text': 'They have Minecraft servers?', 'start': 383.25, 'duration': 1.59},
#  {'text': 'Hostinger is a web hosting provider',
#   'start': 384.84,
#   'duration': 1.77},
#  {'text': 'and internet domain registrar.', 'start': 386.61, 'duration': 1.38},
#  {'text': 'Basically what that\nmeans is that they take',
#   'start': 387.99,
#   'duration': 1.65},
#  {'text': 'all of the technologies necessary',
#   'start': 389.64,
#   'duration': 1.65},
#  {'text': 'to create a secure\nwebsite or host a server,',
#   'start': 391.29,
#   'duration': 2.73},
#  {'text': 'and they bring it into one place.',
#   'start': 394.02,
#   'duration': 1.62},
#  {'text': "If that sounds confusing\nto you, don't worry.",
#   'start': 395.64,
#   'duration': 1.77},
#  {'text': 'They have tutorials and\ndedicated 24/7 customer service',
#   'start': 397.41,
#   'duration': 3.39},
#  {'text': 'and they make it so easy.', 'start': 400.8, 'duration': 2.55},
#  {'text': 'I decided to use their\nWordPress hosting plan',
#   'start': 403.35,
#   'duration': 2.28},
#  {'text': 'because I made a website\nfrom scratch before',
#   'start': 405.63,
#   'duration': 2.64},
#  {'text': 'and it did not go well.', 'start': 408.27, 'duration': 1.47},
#  {'text': 'Couple of you had some issues.', 'start': 409.74, 'duration': 1.83},
#  {'text': 'Just everything was wrong with it.',
#   'start': 411.57,
#   'duration': 1.71},
#  {'text': 'Another issue, it seems completely',
#   'start': 413.28,
#   'duration': 2.25},
#  {'text': 'or mostly unoptimized for mobile.',
#   'start': 415.53,
#   'duration': 2.25},
#  {'text': 'Building a website is hard,\nbut Hostinger makes it easy.',
#   'start': 417.78,
#   'duration': 3.45},
#  {'text': 'WordPress has a bunch of themes',
#   'start': 421.23,
#   'duration': 1.44},
#  {'text': 'and plugins available for free', 'start': 422.67, 'duration': 1.5},
#  {'text': 'and there are no limits on\ndesign or functionality.',
#   'start': 424.17,
#   'duration': 2.37},
#  {'text': 'So you can fully customize your website',
#   'start': 426.54,
#   'duration': 1.5},
#  {'text': 'without even knowing how to code.',
#   'start': 428.04,
#   'duration': 1.41},
#  {'text': 'But why am I making a website at all?',
#   'start': 429.45,
#   'duration': 1.32},
#  {'text': 'Why not just post it somewhere?',
#   'start': 430.77,
#   'duration': 1.44},
#  {'text': 'With my own website,', 'start': 432.21, 'duration': 0.99},
#  {'text': "I'm not competing with\nother content for attention.",
#   'start': 433.2,
#   'duration': 2.61},
#  {'text': 'I get to make my own design options',
#   'start': 435.81,
#   'duration': 1.77},
#  {'text': 'and also I get to make it pretty welcoming',
#   'start': 437.58,
#   'duration': 2.49},
#  {'text': "for people who aren't\nsuper familiar with code.",
#   'start': 440.07,
#   'duration': 2.13},
#  {'text': 'It was super easy to\ndo and it let me focus',
#   'start': 442.2,
#   'duration': 2.01},
#  {'text': 'on the thing I actually\ncare about, the content.',
#   'start': 444.21,
#   'duration': 2.49},
#  {'text': 'I love making these videos,', 'start': 446.7, 'duration': 1.56},
#  {'text': 'but it sometimes sucks because\nI need to cut out so much',
#   'start': 448.26,
#   'duration': 2.67},
#  {'text': "because it's not super relevant",
#   'start': 450.93,
#   'duration': 2.01},
#  {'text': "or it's not super interesting.", 'start': 452.94, 'duration': 1.68},
#  {'text': 'Like, it makes a better video,', 'start': 454.62, 'duration': 1.11},
#  {'text': "but it's just kind of frustrating.",
#   'start': 455.73,
#   'duration': 1.47},
#  {'text': 'But now I have this website.', 'start': 457.2, 'duration': 1.95},
#  {'text': "Okay, it's time for me to\npitch you on Hostinger.",
#   'start': 459.15,
#   'duration': 2.13},
#  {'text': 'I really recommend that you\nmake a personal website.',
#   'start': 461.28,
#   'duration': 2.31},
#  {'text': "It's a really great way\nto set yourself apart",
#   'start': 463.59,
#   'duration': 1.83},
#  {'text': 'if you have a CV or a\nportfolio or a resume.',
#   'start': 465.42,
#   'duration': 3.15},
#  {'text': "It's a very small investment in yourself,",
#   'start': 468.57,
#   'duration': 1.98},
#  {'text': 'yet it does so much.', 'start': 470.55, 'duration': 1.35},
#  {'text': 'If you use our code ANSWER at checkout,',
#   'start': 471.9,
#   'duration': 2.22},
#  {'text': 'you can get 10% off on\ntop of ongoing offers',
#   'start': 474.12,
#   'duration': 3.0},
#  {'text': 'like their massive Black\nFriday sale going on right now.',
#   'start': 477.12,
#   'duration': 2.85},
#  {'text': 'Thanks again to Hostinger\nfor sponsoring this video.',
#   'start': 479.97,
#   'duration': 2.31},
#  {'text': 'Now that we know that Japanese\ninternet looks different,',
#   'start': 482.28,
#   'duration': 2.82},
#  {'text': "let's figure out why.", 'start': 485.1, 'duration': 1.92},
#  {'text': "So I've just spent the past\nfew weeks doing more research.",
#   'start': 487.02,
#   'duration': 2.73},
#  {'text': 'I really thought that I had\nfinished the hard part, but no.',
#   'start': 489.75,
#   'duration': 3.57},
#  {'text': 'I actually ended up turning\nback to the original theory',
#   'start': 493.32,
#   'duration': 2.31},
#  {'text': 'because if they were right', 'start': 495.63, 'duration': 1.26},
#  {'text': 'that Japanese web design is different,',
#   'start': 496.89,
#   'duration': 1.86},
#  {'text': 'I might as well see if their\nreasoning is true as well.',
#   'start': 498.75,
#   'duration': 2.37},
#  {'text': 'Now, the author had a bunch of ideas,',
#   'start': 501.12,
#   'duration': 1.5},
#  {'text': 'but the three that really stood out to me',
#   'start': 502.62,
#   'duration': 1.71},
#  {'text': 'were characters, culture, and technology',
#   'start': 504.33,
#   'duration': 2.88},
#  {'text': 'because these also kept\ncoming up in my Twitter DMs.',
#   'start': 507.21,
#   'duration': 2.52},
#  {'text': "So let's test them out one by\none, starting with characters.",
#   'start': 509.73,
#   'duration': 3.72},
#  {'text': 'Did you know that Japanese characters',
#   'start': 513.45,
#   'duration': 1.8},
#  {'text': 'are literally built different?', 'start': 515.25, 'duration': 1.74},
#  {'text': 'You see, Chinese, Japanese,\nand Korean writing systems',
#   'start': 516.99,
#   'duration': 2.46},
#  {'text': 'share a bunch of logographic characters.',
#   'start': 519.45,
#   'duration': 2.31},
#  {'text': 'These are individual symbols\nthat represent whole words.',
#   'start': 521.76,
#   'duration': 3.12},
#  {'text': 'The sheer amount of these\nCJK characters in existence',
#   'start': 524.88,
#   'duration': 3.39},
#  {'text': 'lead to massive font file sizes.',
#   'start': 528.27,
#   'duration': 2.67},
#  {'text': "For comparison, this is a font\nthat's designed to support",
#   'start': 530.94,
#   'duration': 3.0},
#  {'text': 'Greek, Cyrillic, and\nLatin-based writing systems.',
#   'start': 533.94,
#   'duration': 3.18},
#  {'text': 'It contains less than 4,000 glyphs.',
#   'start': 537.12,
#   'duration': 2.58},
#  {'text': "That's typography speak for a\nrepresentation of a character.",
#   'start': 539.7,
#   'duration': 2.94},
#  {'text': 'These are three different glyphs.',
#   'start': 542.64,
#   'duration': 1.47},
#  {'text': "Now let's look at a font that supports",
#   'start': 544.11,
#   'duration': 1.71},
#  {'text': 'all of those languages', 'start': 545.82, 'duration': 1.32},
#  {'text': 'as well as Chinese, Japanese, and Korean.',
#   'start': 547.14,
#   'duration': 3.36},
#  {'text': 'Keep in mind,', 'start': 550.5, 'duration': 0.833},
#  {'text': 'these writing systems do\nnot have capital letters.',
#   'start': 551.333,
#   'duration': 3.277},
#  {'text': "It's so much more.", 'start': 554.61, 'duration': 1.56},
#  {'text': 'So this means that Japanese websites',
#   'start': 556.17,
#   'duration': 1.68},
#  {'text': 'have significantly fewer font options,',
#   'start': 557.85,
#   'duration': 2.16},
#  {'text': 'since not many designers want\nto take on this challenge.',
#   'start': 560.01,
#   'duration': 2.73},
#  {'text': 'The fonts that do exist might\nload in a little more slowly',
#   'start': 562.74,
#   'duration': 2.58},
#  {'text': 'compared to other writing systems',
#   'start': 565.32,
#   'duration': 1.38},
#  {'text': "since they're pulling from\nlibraries that are massive.",
#   'start': 566.7,
#   'duration': 2.55},
#  {'text': 'And finally, that lack of capitalization',
#   'start': 569.25,
#   'duration': 1.89},
#  {'text': 'means that graphic designers lose a tool',
#   'start': 571.14,
#   'duration': 1.8},
#  {'text': 'for creating visual hierarchy.', 'start': 572.94, 'duration': 1.62},
#  {'text': 'These are all factors\nthat could realistically',
#   'start': 574.56,
#   'duration': 1.92},
#  {'text': 'cause design differences between regions',
#   'start': 576.48,
#   'duration': 2.16},
#  {'text': 'that use CJK characters\nand the rest of the world,',
#   'start': 578.64,
#   'duration': 3.63},
#  {'text': "except it doesn't.", 'start': 582.27, 'duration': 2.1},
#  {'text': 'From what I found, other\nregions that use CJK characters',
#   'start': 584.37,
#   'duration': 3.09},
#  {'text': "don't exhibit the same\ndesign patterns as Japan.",
#   'start': 587.46,
#   'duration': 2.67},
#  {'text': 'So we learned something\ninteresting, which is useless.',
#   'start': 590.13,
#   'duration': 3.33},
#  {'text': 'Put that on my tombstone.', 'start': 593.46, 'duration': 2.16},
#  {'text': 'Anyway.', 'start': 595.62, 'duration': 0.93},
#  {'text': 'But what about culture?', 'start': 596.55, 'duration': 1.02},
#  {'text': 'This was a tricky one\nbecause I was a STEM student,',
#   'start': 597.57,
#   'duration': 2.22},
#  {'text': "so I don't have a lot of the\ndomain knowledge necessary",
#   'start': 599.79,
#   'duration': 2.13},
#  {'text': 'to accurately identify and\ncompare global cultures.',
#   'start': 601.92,
#   'duration': 3.51},
#  {'text': 'However, being a STEM student also means',
#   'start': 605.43,
#   'duration': 2.52},
#  {'text': "that that didn't stop me from trying.",
#   'start': 607.95,
#   'duration': 2.31},
#  {'text': 'I started off by using\ngeographic proximity,',
#   'start': 610.26,
#   'duration': 2.097},
#  {'text': 'but that failed.', 'start': 612.357, 'duration': 0.933},
#  {'text': 'So then I used a binary identifier',
#   'start': 613.29,
#   'duration': 2.28},
#  {'text': 'for if a country was\npart of the global north',
#   'start': 615.57,
#   'duration': 1.92},
#  {'text': 'or global south.', 'start': 617.49, 'duration': 1.05},
#  {'text': 'Also no pattern.', 'start': 618.54, 'duration': 0.99},
#  {'text': 'But like I said,', 'start': 619.53, 'duration': 0.833},
#  {'text': "I don't know if this is the\nbest way to compare cultures.",
#   'start': 620.363,
#   'duration': 2.377},
#  {'text': "However, given what I've found,",
#   'start': 622.74,
#   'duration': 1.77},
#  {'text': "I'm just not convinced that culture",
#   'start': 624.51,
#   'duration': 2.1},
#  {'text': "is the primary cause of\nJapan's unique web design.",
#   'start': 626.61,
#   'duration': 3.0},
#  {'text': "Thus, all we're left with is technology.",
#   'start': 629.61,
#   'duration': 2.1},
#  {'text': 'How hardware and software', 'start': 631.71, 'duration': 1.65},
#  {'text': 'shape the way websites are designed today',
#   'start': 633.36,
#   'duration': 2.28},
#  {'text': "and why Japan didn't follow that path.",
#   'start': 635.64,
#   'duration': 2.67},
#  {'text': "So let's start from the beginning",
#   'start': 638.31,
#   'duration': 2.49},
#  {'text': 'and go on a journey through time.',
#   'start': 640.8,
#   'duration': 2.43},
#  {'text': 'The worldwide web is invented', 'start': 643.23, 'duration': 1.2},
#  {'text': 'as a way for nerds to share documents,',
#   'start': 644.43,
#   'duration': 1.38},
#  {'text': 'which is why every\nwebsite looked like this.',
#   'start': 645.81,
#   'duration': 2.31},
#  {'text': 'Not good.', 'start': 648.12, 'duration': 0.833},
#  {'text': 'But the people knew it\ncould be so much more.',
#   'start': 648.953,
#   'duration': 1.837},
#  {'text': 'It could share ideas, house\nbusinesses, share pictures of...',
#   'start': 650.79,
#   'duration': 3.36},
#  {'text': 'At a whopping 0.05 megabits per second,',
#   'start': 654.15,
#   'duration': 3.45},
#  {'text': 'the average person could access', 'start': 657.6, 'duration': 1.62},
#  {'text': 'a whole new world of\ninformation pixel by pixel,',
#   'start': 659.22,
#   'duration': 4.35},
#  {'text': "but that didn't stop people\nfrom enjoying the internet.",
#   'start': 663.57,
#   'duration': 1.95},
#  {'text': "I mean, if you don't know any better,",
#   'start': 665.52,
#   'duration': 1.23},
#  {'text': "I guess it's not its own circle of hell.",
#   'start': 666.75,
#   'duration': 1.8},
#  {'text': 'However, the internet takes off.',
#   'start': 668.55,
#   'duration': 2.52},
#  {'text': 'In just two years,', 'start': 671.07, 'duration': 0.9},
#  {'text': 'we go from 2000 websites to over a million',
#   'start': 671.97,
#   'duration': 2.88},
#  {'text': 'with no signs of slowing down.', 'start': 674.85, 'duration': 1.92},
#  {'text': 'Scripting languages make\nwebsites more interactive,',
#   'start': 676.77,
#   'duration': 2.52},
#  {'text': 'almost too interactive.', 'start': 679.29, 'duration': 1.02},
#  {'text': "This is the internet.\nI'm not here to interact.",
#   'start': 680.31,
#   'duration': 1.65},
#  {'text': 'And Flash gave designers so much freedom',
#   'start': 681.96,
#   'duration': 2.49},
#  {'text': 'and gave children so many iconic games.',
#   'start': 684.45,
#   'duration': 3.0},
#  {'text': "The question wasn't what can we do,",
#   'start': 687.45,
#   'duration': 2.04},
#  {'text': "it was what can't we do?", 'start': 689.49, 'duration': 2.133},
#  {'text': 'And sure, if you were using', 'start': 692.49, 'duration': 0.96},
#  {'text': 'the wrong browser or browser version,',
#   'start': 693.45,
#   'duration': 1.53},
#  {'text': 'some websites might not work,', 'start': 694.98, 'duration': 1.59},
#  {'text': 'but when they did, it was glorious.',
#   'start': 696.57,
#   'duration': 2.94},
#  {'text': "So why don't websites\nlook like this anymore?",
#   'start': 699.51,
#   'duration': 2.1},
#  {'text': "Why aren't they diverse\nand chaotic and beautiful?",
#   'start': 701.61,
#   'duration': 3.12},
#  {'text': 'Well, two reasons.', 'start': 704.73, 'duration': 1.41},
#  {'text': 'One, a lot of those 90s\nwebsites were unstable,',
#   'start': 706.14,
#   'duration': 2.58},
#  {'text': 'unsecure, and inaccessible.', 'start': 708.72, 'duration': 1.59},
#  {'text': 'So standards were established\nto make sure websites',
#   'start': 710.31,
#   'duration': 1.83},
#  {'text': 'use the same building blocks\nand, two, search engines.',
#   'start': 712.14,
#   'duration': 4.05},
#  {'text': 'While early search\nengines used information',
#   'start': 716.19,
#   'duration': 2.19},
#  {'text': 'submitted or curated by\nwebmasters and web users,',
#   'start': 718.38,
#   'duration': 3.21},
#  {'text': 'they evolved to use bots', 'start': 721.59, 'duration': 1.56},
#  {'text': 'that crawled the internet,\nscraped information,',
#   'start': 723.15,
#   'duration': 2.46},
#  {'text': 'and informed search results.', 'start': 725.61, 'duration': 1.77},
#  {'text': 'Initially, search engines just checked',
#   'start': 727.38,
#   'duration': 1.62},
#  {'text': "if a website's contents\ncontained search terms,",
#   'start': 729.0,
#   'duration': 2.64},
#  {'text': 'but then webmasters just\nstarted spamming key terms',
#   'start': 731.64,
#   'duration': 2.43},
#  {'text': 'to get to the top of search results.',
#   'start': 734.07,
#   'duration': 1.5},
#  {'text': 'So then search engines started valuing',
#   'start': 735.57,
#   'duration': 2.19},
#  {'text': 'how often a website is\nreferenced by other websites.',
#   'start': 737.76,
#   'duration': 3.0},
#  {'text': 'But then companies started paying',
#   'start': 740.76,
#   'duration': 1.62},
#  {'text': 'to be linked on random websites',
#   'start': 742.38,
#   'duration': 2.49},
#  {'text': 'to get to the top of search results.',
#   'start': 744.87,
#   'duration': 1.68},
#  {'text': 'This cycle continued until eventually',
#   'start': 746.55,
#   'duration': 2.19},
#  {'text': 'search engines became so\npowerful and so sophisticated',
#   'start': 748.74,
#   'duration': 3.33},
#  {'text': 'that websites had no choice\nbut to play by the rules.',
#   'start': 752.07,
#   'duration': 2.88},
#  {'text': 'Web design became more\nstructured and uniform',
#   'start': 754.95,
#   'duration': 1.98},
#  {'text': 'to make it easier for\nsearch engines to find them.',
#   'start': 756.93,
#   'duration': 2.79},
#  {'text': 'Now, you might think that the differences',
#   'start': 759.72,
#   'duration': 1.59},
#  {'text': 'in how search engines work', 'start': 761.31, 'duration': 1.35},
#  {'text': 'is what caused websites to look\ndifferent around the world,',
#   'start': 762.66,
#   'duration': 3.36},
#  {'text': 'except Google is basically\nthe only search engine',
#   'start': 766.02,
#   'duration': 2.97},
#  {'text': "and it's been that way since 2005.",
#   'start': 768.99,
#   'duration': 2.13},
#  {'text': 'In every country except China,', 'start': 771.12, 'duration': 1.26},
#  {'text': 'websites would wanna\noptimize for Google search.',
#   'start': 772.38,
#   'duration': 2.55},
#  {'text': 'So what else could have\ncaused Japanese web design',
#   'start': 774.93,
#   'duration': 1.95},
#  {'text': 'to fracture off?', 'start': 776.88, 'duration': 1.02},
#  {'text': 'Well, we need to consider this.', 'start': 777.9, 'duration': 1.68},
#  {'text': 'The rise of smartphones.', 'start': 779.58, 'duration': 1.92},
#  {'text': "It's 2007, and suddenly\nall of these websites",
#   'start': 781.5,
#   'duration': 2.433},
#  {'text': 'that were designed for desktop viewing',
#   'start': 783.933,
#   'duration': 2.127},
#  {'text': 'are too difficult to navigate\non small phone screens',
#   'start': 786.06,
#   'duration': 2.61},
#  {'text': 'and too data-heavy to\nload on limited plans.',
#   'start': 788.67,
#   'duration': 2.88},
#  {'text': '- You know, you can help me out,',
#   'start': 791.55,
#   'duration': 1.05},
#  {'text': "if you're on wifi, if\nyou could just get off.",
#   'start': 792.6,
#   'duration': 2.46},
#  {'text': '- The easy answer was to\nstart simplifying navigation,',
#   'start': 795.06,
#   'duration': 2.85},
#  {'text': 'reducing content, making things bigger.',
#   'start': 797.91,
#   'duration': 3.18},
#  {'text': 'This all resulted in\nthis minimalist design',
#   'start': 801.09,
#   'duration': 2.37},
#  {'text': "that we're all familiar\nwith, that we call modern.",
#   'start': 803.46,
#   'duration': 3.39},
#  {'text': "So it seems like it\nwasn't language or culture",
#   'start': 806.85,
#   'duration': 2.49},
#  {'text': "that caused Japan's web design", 'start': 809.34, 'duration': 1.47},
#  {'text': 'to fracture off from\nthe rest of the world.',
#   'start': 810.81,
#   'duration': 2.04},
#  {'text': "Instead, it's that their websites",
#   'start': 812.85,
#   'duration': 1.53},
#  {'text': 'never adopted the practices\nfor mobile-friendly web design.',
#   'start': 814.38,
#   'duration': 3.75},
#  {'text': 'But why?', 'start': 818.13, 'duration': 1.29},
#  {'text': "And that's because the\nJapanese smartphone revolution",
#   'start': 819.42,
#   'duration': 2.49},
#  {'text': 'happened about 10 years\nbefore the rest of the world.',
#   'start': 821.91,
#   'duration': 2.7},
#  {'text': "Their phones had email in '99,\ncameras in 2000, 3G by 2001.",
#   'start': 824.61,
#   'duration': 5.0},
#  {'text': 'They were so far ahead\nof the rest of the world,',
#   'start': 830.49,
#   'duration': 2.13},
#  {'text': "but domestic companies didn't\nfeel the need to spread abroad",
#   'start': 832.62,
#   'duration': 2.88},
#  {'text': 'because they were already\nprofitable enough in Japan.',
#   'start': 835.5,
#   'duration': 2.88},
#  {'text': 'But when the Western web began\nsimplifying for the iPhone,',
#   'start': 838.38,
#   'duration': 3.03},
#  {'text': "Japanese web designers\ndidn't need to do that",
#   'start': 841.41,
#   'duration': 2.04},
#  {'text': "because Japanese people\nweren't using the iPhone.",
#   'start': 843.45,
#   'duration': 3.24},
#  {'text': 'Now, there are a couple of other reasons',
#   'start': 846.69,
#   'duration': 1.56},
#  {'text': 'like risk aversion that\nmight influence this,',
#   'start': 848.25,
#   'duration': 2.16},
#  {'text': 'but it really seems', 'start': 850.41, 'duration': 1.08},
#  {'text': "like Japan's relationship with technology,",
#   'start': 851.49,
#   'duration': 2.22},
#  {'text': 'specifically outdated technology,',
#   'start': 853.71,
#   'duration': 1.89},
#  {'text': 'is the main reason why Japanese\ninternet looks so different.',
#   'start': 855.6,
#   'duration': 3.18},
#  {'text': 'And after looking at thousands of websites',
#   'start': 858.78,
#   'duration': 1.95},
#  {'text': 'and learning the history of the internet,',
#   'start': 860.73,
#   'duration': 1.83},
#  {'text': "I realized that this\nisn't just fun trivia.",
#   'start': 862.56,
#   'duration': 3.21},
#  {'text': "This is relevant to us even\nif you're not in Japan,",
#   'start': 865.77,
#   'duration': 2.4},
#  {'text': 'even if you never intend to\ngo to a Japanese website,',
#   'start': 868.17,
#   'duration': 2.88},
#  {'text': 'because these websites are artifacts',
#   'start': 871.05,
#   'duration': 1.83},
#  {'text': 'of how hardware and software,', 'start': 872.88, 'duration': 2.07},
#  {'text': 'the infrastructure of the internet',
#   'start': 874.95,
#   'duration': 1.98},
#  {'text': 'tangibly shapes the way\nwe consume information.',
#   'start': 876.93,
#   'duration': 3.33},
#  {'text': "I can't process this because\nI don't read Japanese.",
#   'start': 880.26,
#   'duration': 3.27},
#  {'text': 'But similarly, I get overwhelmed\nwhen looking at old Reddit.',
#   'start': 883.53,
#   'duration': 2.94},
#  {'text': 'The small images, the amount of text,',
#   'start': 886.47,
#   'duration': 1.95},
#  {'text': "it's hard for me to understand", 'start': 888.42, 'duration': 1.35},
#  {'text': "because I'm not used to to it.", 'start': 889.77, 'duration': 1.62},
#  {'text': "Now, I want you to think about\ntoday's web technologies.",
#   'start': 891.39,
#   'duration': 2.46},
#  {'text': 'Infinite scrolling,\nalgorithmically selected content,',
#   'start': 893.85,
#   'duration': 3.0},
#  {'text': 'cuts every two seconds.', 'start': 896.85, 'duration': 2.01},
#  {'text': "I'm not saying it's good or bad,",
#   'start': 898.86,
#   'duration': 1.23},
#  {'text': 'but it sure as heck seems\nlike it can impact us.',
#   'start': 900.09,
#   'duration': 2.79},
#  {'text': 'And with the internet', 'start': 902.88, 'duration': 0.87},
#  {'text': 'constantly in our pockets or our hands,',
#   'start': 903.75,
#   'duration': 2.733},
#  {'text': 'it can shape the way we see the world.',
#   'start': 907.32,
#   'duration': 2.19},
#  {'text': "Yes, I'm just saying the\nmedium is the message.",
#   'start': 909.51,
#   'duration': 1.95},
#  {'text': 'But either way, have a lovely day.',
#   'start': 911.46,
#   'duration': 2.733}]

# %% [markdown]
# ## Using NLTK (Natural Language Toolkit) to find keywords

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.1)

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Download NLTK resources (if not already downloaded)
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# Check if transcript_text is already a string, if not, convert it to a string
if not isinstance(transcript, str):
    transcript_text = str(transcript)

# Tokenize the transcript text and convert to lowercase
words = word_tokenize(transcript_text)
lowercase_words = [word.lower() for word in words]

# %%
# Define additional stopwords
additional_stopwords = {'I', 'So', 'really', 'search', 'need', 'want', 'know', 'like', 'see', 'let', 'the', 'it', 'you', 'that', 'he', 'she', 'we', 'they', 'my', 'your', 'his', 'her', 'its', 'our', 'their', 'a', 'an', 'and', 'but', 'or', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'should', 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'couldn', 'didn', "doesn't", 'hadn', 'hasn', "hasn't", 'haven', 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"}
 # Add more words as needed

# Extend the default stopwords list with the additional stopwords
stop_words = set(stopwords.words('english')).union(additional_stopwords)

# Remove punctuation and stopwords
filtered_words = [word for word in words if word.isalnum() and word not in stop_words]

# %%
# Create a frequency distribution
freq_dist = nltk.FreqDist(filtered_words)

# Get the most common words as keywords
num_keywords = 10  # Adjust the number of keywords as needed
keywords = [word for word, freq in freq_dist.most_common(num_keywords)]

# %%
# Print or use the keywords as needed
print("Keywords:")
for keyword in keywords:
    print(keyword)
# Out:
# Keywords:
# websites
# web
# Japan
# design
# website
# internet
# Japanese
# world
# different
# video

# %% [markdown]
# # Iterate

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
from youtube_transcript_api import YouTubeTranscriptApi


# List of video URLs
video_links = [

'https://www.youtube.com/watch?v=knj9NQqSQDQ',
'https://www.youtube.com/watch?v=kw9hrud5CFE',
'https://www.youtube.com/watch?v=w_wdXln2jq8',
'https://www.youtube.com/watch?v=6fgBNMKaYuM',
'https://www.youtube.com/watch?v=OzEwM-A_HAM',
'https://www.youtube.com/watch?v=PGvWRzpldPM',
'https://www.youtube.com/watch?v=8kYfdkdzGUg',
'https://www.youtube.com/watch?v=5eLmrSOn9vw',
'https://www.youtube.com/watch?v=1viUcfZ36Qs',
'https://www.youtube.com/watch?v=PGvWRzpldPM',
'https://www.youtube.com/watch?v=zGpc0Y2ZY9A',
'https://www.youtube.com/watch?v=vu5OtDlvsIo',
'https://www.youtube.com/watch?v=SNNxM8l65Hc',
'https://www.youtube.com/watch?v=Os4XWBduMNM',
'https://www.youtube.com/watch?v=79VwfZTSRGc',
'https://www.youtube.com/watch?v=6W5d89zUC0g',
'https://www.youtube.com/watch?v=Jlpab0F3Tpw',
'https://www.youtube.com/watch?v=a4j64QitsPE',
'https://www.youtube.com/watch?v=t711B2wCyaY',
'https://www.youtube.com/watch?v=uvjjOtxSKdQ',
'https://www.youtube.com/watch?v=uWLjlytgfy8',
'https://www.youtube.com/watch?v=klcoEl0N53w',
'https://www.youtube.com/watch?v=Wa8uVazArlE',
'https://www.youtube.com/watch?v=e7OewOaMtC8',
'https://www.youtube.com/watch?v=wpLxxRSGp8w',
'https://www.youtube.com/watch?v=K12jzd4W3Ek',
'https://www.youtube.com/watch?v=RFVgo8hRVM4',
'https://www.youtube.com/watch?v=4Stzj2_Rlo4'





]




# Create an empty list to store the transcripts
transcripts = []

# Iterate through the list of video links
for video_link in video_links:
    # Extract the video ID from the URL (assuming the URL format is consistent)
    video_id = video_link.split('v=')[1]

    try:
        # Get the transcript for the video
        transcript = YouTubeTranscriptApi.get_transcript(video_id)

        # Add the transcript to the list
        transcripts.append({
            'video_id': video_id,
            'transcript': transcript
        })

    except Exception as e:
        print(f"Error processing video {video_link}: {e}")

# Save the transcripts to a JSON file
output_file = '/content/drive/MyDrive/transcripts.json'
with open(output_file, 'w', encoding='utf-8') as json_file:
    json.dump(transcripts, json_file, ensure_ascii=False, indent=4)

print(f"Transcripts saved to {output_file}")
# Out:
# Error processing video https://www.youtube.com/watch?v=K12jzd4W3Ek:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=K12jzd4W3Ek! This is most likely caused by:
#
# No transcripts were found for any of the requested language codes: ('en',)
#
# For this video (K12jzd4W3Ek) transcripts are available in the following languages:
#
# (MANUALLY CREATED)
# None
#
# (GENERATED)
#  - ja ("Japanese (auto-generated)")[TRANSLATABLE]
#
# (TRANSLATION LANGUAGES)
#  - af ("Afrikaans")
#  - ak ("Akan")
#  - sq ("Albanian")
#  - am ("Amharic")
#  - ar ("Arabic")
#  - hy ("Armenian")
#  - as ("Assamese")
#  - ay ("Aymara")
#  - az ("Azerbaijani")
#  - bn ("Bangla")
#  - eu ("Basque")
#  - be ("Belarusian")
#  - bho ("Bhojpuri")
#  - bs ("Bosnian")
#  - bg ("Bulgarian")
#  - my ("Burmese")
#  - ca ("Catalan")
#  - ceb ("Cebuano")
#  - zh-Hans ("Chinese (Simplified)")
#  - zh-Hant ("Chinese (Traditional)")
#  - co ("Corsican")
#  - hr ("Croatian")
#  - cs ("Czech")
#  - da ("Danish")
#  - dv ("Divehi")
#  - nl ("Dutch")
#  - en ("English")
#  - eo ("Esperanto")
#  - et ("Estonian")
#  - ee ("Ewe")
#  - fil ("Filipino")
#  - fi ("Finnish")
#  - fr ("French")
#  - gl ("Galician")
#  - lg ("Ganda")
#  - ka ("Georgian")
#  - de ("German")
#  - el ("Greek")
#  - gn ("Guarani")
#  - gu ("Gujarati")
#  - ht ("Haitian Creole")
#  - ha ("Hausa")
#  - haw ("Hawaiian")
#  - iw ("Hebrew")
#  - hi ("Hindi")
#  - hmn ("Hmong")
#  - hu ("Hungarian")
#  - is ("Icelandic")
#  - ig ("Igbo")
#  - id ("Indonesian")
#  - ga ("Irish")
#  - it ("Italian")
#  - ja ("Japanese")
#  - jv ("Javanese")
#  - kn ("Kannada")
#  - kk ("Kazakh")
#  - km ("Khmer")
#  - rw ("Kinyarwanda")
#  - ko ("Korean")
#  - kri ("Krio")
#  - ku ("Kurdish")
#  - ky ("Kyrgyz")
#  - lo ("Lao")
#  - la ("Latin")
#  - lv ("Latvian")
#  - ln ("Lingala")
#  - lt ("Lithuanian")
#  - lb ("Luxembourgish")
#  - mk ("Macedonian")
#  - mg ("Malagasy")
#  - ms ("Malay")
#  - ml ("Malayalam")
#  - mt ("Maltese")
#  - mi ("Māori")
#  - mr ("Marathi")
#  - mn ("Mongolian")
#  - ne ("Nepali")
#  - nso ("Northern Sotho")
#  - no ("Norwegian")
#  - ny ("Nyanja")
#  - or ("Odia")
#  - om ("Oromo")
#  - ps ("Pashto")
#  - fa ("Persian")
#  - pl ("Polish")
#  - pt ("Portuguese")
#  - pa ("Punjabi")
#  - qu ("Quechua")
#  - ro ("Romanian")
#  - ru ("Russian")
#  - sm ("Samoan")
#  - sa ("Sanskrit")
#  - gd ("Scottish Gaelic")
#  - sr ("Serbian")
#  - sn ("Shona")
#  - sd ("Sindhi")
#  - si ("Sinhala")
#  - sk ("Slovak")
#  - sl ("Slovenian")
#  - so ("Somali")
#  - st ("Southern Sotho")
#  - es ("Spanish")
#  - su ("Sundanese")
#  - sw ("Swahili")
#  - sv ("Swedish")
#  - tg ("Tajik")
#  - ta ("Tamil")
#  - tt ("Tatar")
#  - te ("Telugu")
#  - th ("Thai")
#  - ti ("Tigrinya")
#  - ts ("Tsonga")
#  - tr ("Turkish")
#  - tk ("Turkmen")
#  - uk ("Ukrainian")
#  - ur ("Urdu")
#  - ug ("Uyghur")
#  - uz ("Uzbek")
#  - vi ("Vietnamese")
#  - cy ("Welsh")
#  - fy ("Western Frisian")
#  - xh ("Xhosa")
#  - yi ("Yiddish")
#  - yo ("Yoruba")
#  - zu ("Zulu")
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcripts saved to /content/drive/MyDrive/transcripts.json

# %%
import json
import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
from nltk.corpus import stopwords

# Download NLTK data (if not already downloaded)
nltk.download('punkt')
nltk.download('stopwords')

# Load the JSON file containing transcripts
with open('/content/drive/MyDrive/transcripts.json', 'r', encoding='utf-8') as json_file:
    transcripts = json.load(json_file)

# Initialize a list to store all words
all_words = []

# Tokenize and preprocess each transcript
for entry in transcripts:
    transcript_text = ' '.join([item['text'] for item in entry['transcript']])
    words = word_tokenize(transcript_text.lower())  # Tokenize and convert to lowercase
    all_words.extend(words)

# Filter out stopwords

additional_stopwords = {'20', '30', '50', '12', 'ja', 'knew', 'later', 'anyway', 'oddly', 'eh', 'obviously', 'basically', 'instead', 'overall', 'oriented', 'solely', 'whether', 'e', 'allows' ,'specifically' ,'either', 'applies','k', 'yep', 'honestly', 'gosh', 'whoa', 'damn', 'went', 'check', 'ah', 'I', 'So', 'a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'along', 'already', 'also', 'an', 'and', 'another', 'any', 'anywhere', 'are', 'aren', "aren't", 'around', 'as', 'at', 'away', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'come', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'done', 'down', 'during', 'each', 'else', 'ever', 'every', 'everyone', 'everything', 'few', 'fine', 'first', 'five', 'for', 'four', 'from', 'further', 'get', 'getting', 'go', 'god', 'good', 'got', 'guy', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', 'her', 'here', 'hey', 'him', 'his', 'how', 'however', 'i', 'if', 'in', 'indeed', 'into', 'is', 'isn', "isn't", 'it', "it's", 'its', 'just', 'kind', 'know', 'last', 'let', 'like', 'll', 'long', 'look', 'lot', 'made', 'make', 'making', 'man', 'many', 'may', 'me', 'mean', 'means', 'might', 'more', 'most', 'much', 'must', 'mustn', "mustn't", 'my', 'name', 'need', 'never', 'nevertheless', 'next', 'nice', 'no', 'none', 'nor', 'not', 'nothing', 'now', 'nowhere', 'of', 'off', 'often', 'oh', 'on', 'once', 'one', 'only', 'or', 'other', 'our', 'out', 'over', 'own', 'particular', 'people', 'perhaps', 'pretty', 'quite', 'really', 'real', 're', 's', 'said', 'same', 'say', 'saying', 'seems', 'seen', 'several', 'shall', 'shan', "shan't", 'she', 'should', 'shouldn', "shouldn't", 'since', 'so', 'some', 'someone', 'something', 'sometimes', 'still', 'stop', 'stuff', 'sure', 'ta', 'take', 'than', 'that', 'the', 'their', 'them', 'then', 'there', 'these', 'they', 'thing', 'things', 'think', 'this', 'those', 'though', 'three', 'through', 'to', 'too', 'trying', 'two', 'uh', 'under', 'up', 'us', 'use', 'usually', 've', 'very', 'wait', 'want', 'way', 'we', 'well', 'were', 'weren', "weren't", 'what', 'when', 'where', 'wherever', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'without', 'won', "won't", 'work', 'would', 'wouldn', "wouldn't", 'y', 'yeah', 'yes', 'yet', 'you', 'your', 'add', 'great', 'feel', 'anything', 'keep', 'always', 'wow', 'place', 'looking', 'enough', 'try', 'second', 'end', 'able', 'makes', 'least', 'gets', 'causing', 'help', 'cool', 'find', 'sorry', 'left', 'finally', 'literally', 'whole', 'reason', 'close', 'yo', 'times', 'top', 'today', 'using', 'stating', '10', 'different', 'definitely', 'tell', 'far', 'hear', 'course', 'wo', 'whatever', 'coming', 'lost', 'right', 'okay', 'na', 'gon', 'going', 'see', 'actually', 'even', 'could', 'back', 'bro', 'ca', 'thank', 'give', 'little', 'um', 'maybe', 'dude', 'please', 'bit', 'probably', 'put', 'listen', 'idea', 'feels', 'remember', 'six'}

stop_words = set(stopwords.words('english')).union(additional_stopwords)

filtered_words = [word for word in all_words if word.isalnum() and word not in stop_words]


# Calculate word frequencies
fdist = FreqDist(filtered_words)

# Get the most common words as keywords (adjust the number as needed)
num_keywords = 100
keywords = [word for word, freq in fdist.most_common(num_keywords)]

# Print the most common words as keywords
print("Keywords:")
for keyword in keywords:
    print(keyword)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Keywords:
# time
# game
# music
# nick
# team
# guys
# pokemon
# star
# evie
# damage
# money
# skill
# bad
# character
# win
# tommy
# turn
# play
# coins
# brent
# games
# free
# new
# hit
# fight
# big
# start
# lose
# video
# block
# dream
# point
# hate
# stars
# dice
# thought
# move
# best
# attack
# hp
# guess
# sky
# catch
# battle
# better
# run
# true
# type
# day
# phil
# blade
# speed
# works
# die
# points
# chance
# pay
# perfect
# single
# life
# hard
# characters
# item
# universe
# bernie
# mario
# believe
# fuschwan
# roll
# baby
# worry
# love
# level
# random
# fun
# boss
# gym
# shut
# talking
# talk
# crazy
# world
# part
# unit
# trust
# dps
# bowser
# hold
# ice
# number
# ultimate
# plan
# freaking
# almost
# wrong
# call
# land
# buy
# wanted
# kill

# %%
# Calculate word frequencies
fdist = FreqDist(filtered_words)

# Get the most common words as keywords (adjust the number as needed)
num_keywords = 100
keywords = [word for word, freq in fdist.most_common(num_keywords)]

# Print the most common words as keywords
print("Keywords:")
for keyword in keywords:
    print(keyword)

# Calculate the frequency of each keyword
keyword_frequencies = {keyword: fdist[keyword] for keyword in keywords}

# Print the frequency of each keyword
print("\nKeyword Frequencies:")
for keyword, frequency in keyword_frequencies.items():
    print(f"{keyword}: {frequency}")
# Out:
# Keywords:
# time
# game
# music
# nick
# team
# guys
# pokemon
# star
# evie
# damage
# money
# skill
# bad
# character
# win
# tommy
# turn
# play
# coins
# brent
# games
# free
# new
# hit
# fight
# big
# start
# lose
# video
# block
# dream
# point
# hate
# stars
# dice
# thought
# move
# best
# attack
# hp
# guess
# sky
# catch
# battle
# better
# run
# true
# type
# day
# phil
# blade
# speed
# works
# die
# points
# chance
# pay
# perfect
# single
# life
# hard
# characters
# item
# universe
# bernie
# mario
# believe
# fuschwan
# roll
# baby
# worry
# love
# level
# random
# fun
# boss
# gym
# shut
# talking
# talk
# crazy
# world
# part
# unit
# trust
# dps
# bowser
# hold
# ice
# number
# ultimate
# plan
# freaking
# almost
# wrong
# call
# land
# buy
# wanted
# kill
#
# Keyword Frequencies:
# time: 331
# game: 327
# music: 184
# nick: 172
# team: 165
# guys: 155
# pokemon: 142
# star: 139
# evie: 132
# damage: 125
# money: 119
# skill: 115
# bad: 109
# character: 107
# win: 102
# tommy: 100
# turn: 92
# play: 90
# coins: 88
# brent: 88
# games: 86
# free: 79
# new: 79
# hit: 77
# fight: 75
# big: 74
# start: 72
# lose: 72
# video: 70
# block: 69
# dream: 64
# point: 61
# hate: 60
# stars: 59
# dice: 59
# thought: 58
# move: 57
# best: 55
# attack: 54
# hp: 54
# guess: 53
# sky: 53
# catch: 53
# battle: 51
# better: 51
# run: 51
# true: 51
# type: 50
# day: 50
# phil: 49
# blade: 49
# speed: 49
# works: 48
# die: 47
# points: 47
# chance: 47
# pay: 47
# perfect: 47
# single: 47
# life: 46
# hard: 46
# characters: 46
# item: 46
# universe: 45
# bernie: 45
# mario: 45
# believe: 44
# fuschwan: 44
# roll: 44
# baby: 43
# worry: 43
# love: 43
# level: 42
# random: 42
# fun: 42
# boss: 42
# gym: 42
# shut: 41
# talking: 41
# talk: 41
# crazy: 41
# world: 40
# part: 40
# unit: 40
# trust: 39
# dps: 39
# bowser: 38
# hold: 37
# ice: 37
# number: 37
# ultimate: 37
# plan: 36
# freaking: 36
# almost: 35
# wrong: 35
# call: 35
# land: 35
# buy: 35
# wanted: 35
# kill: 34

# %% [markdown]
# Visualisasi

# %%
# !pip install pandas
import pandas as pd

# Buat DataFrame dari kamus keyword_frequencies
df = pd.DataFrame.from_dict(keyword_frequencies, orient='index', columns=['Frekuensi'])

# Urutkan DataFrame berdasarkan frekuensi secara menurun
df = df.sort_values(by='Frekuensi', ascending=False)

# Ambil 20 kata kunci teratas
top_100_keywords = df.head(100)

# Cetak tabel kata kunci teratas
print(top_100_keywords)
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
#         Frekuensi
# time          331
# game          327
# music         184
# nick          172
# team          165
# ...           ...
# call           35
# land           35
# buy            35
# wanted         35
# kill           34
#
# [100 rows x 1 columns]

# %%
top_100_keywords
# Out:
#         Frekuensi
# time          331
# game          327
# music         184
# nick          172
# team          165
# ...           ...
# call           35
# land           35
# buy            35
# wanted         35
# kill           34
#
# [100 rows x 1 columns]

# %%
#tabel
import matplotlib.pyplot as plt
# Ambil 10 kata kunci teratas
top_10_keywords = df.head(10)

# Siapkan data untuk plot
keywords = top_10_keywords.index
frequencies = top_10_keywords['Frekuensi']

# Buat bar graph
plt.figure(figsize=(12, 6))
plt.bar(keywords, frequencies)
plt.xlabel('Kata Kunci')
plt.ylabel('Frekuensi')
plt.title('Top 10 Kata Kunci dengan Frekuensi Terbesar')
plt.xticks(rotation=90)  # Agar label sumbu x tidak tumpang tindih
plt.tight_layout()

# Tampilkan bar graph
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Menggabungkan semua kata kunci menjadi satu teks
top_100_keywords = df.head(100)
keywords100 = top_100_keywords.index
all_keywords_text = ' '.join(keywords100)

# Membuat objek WordCloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_keywords_text)

# Membuat plot word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")  # Menghilangkan sumbu
plt.title('Word Cloud dari keywords')
plt.show()

# %%
import matplotlib.pyplot as plt

# Ambil 100 kata kunci teratas
top_6_keywords = df.head(6)

# Siapkan data untuk pie chart
labels = top_6_keywords.index
sizes = top_6_keywords['Frekuensi']

# Buat pie chart
plt.figure(figsize=(6, 6))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Memastikan pie chart berbentuk lingkaran
plt.show()
